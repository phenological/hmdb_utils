# %% [markdown]
# # HMDB database importer

# %%
import xml.etree.ElementTree as ET
import numpy as np
import pandas as pd

# %%
tree = ET.parse('hmdb_urine/urine_metabolites.xml')
root = tree.getroot()

# %%
def print_element(element, level=0):
    indent = "  " * level
    print(f"{indent}Tag: {element.tag}, Attributes: {element.attrib}")
    
    if element.text and element.text.strip():
        print(f"{indent}  Text: {element.text.strip()}")
    
    for child in element:
        print_element(child, level + 1)

first = True
for child in root:
    if first:
        print_element(child)
        first = False
# Out:
# Tag: {http://www.hmdb.ca}metabolite, Attributes: {}
#   Tag: {http://www.hmdb.ca}version, Attributes: {}
#     Text: 5.0
#   Tag: {http://www.hmdb.ca}creation_date, Attributes: {}
#     Text: 2005-11-16 15:48:42 UTC
#   Tag: {http://www.hmdb.ca}update_date, Attributes: {}
#     Text: 2021-10-13 17:34:04 UTC
#   Tag: {http://www.hmdb.ca}accession, Attributes: {}
#     Text: HMDB0000001
#   Tag: {http://www.hmdb.ca}status, Attributes: {}
#     Text: quantified
#   Tag: {http://www.hmdb.ca}secondary_accessions, Attributes: {}
#     Tag: {http://www.hmdb.ca}accession, Attributes: {}
#       Text: HMDB00001
#     Tag: {http://www.hmdb.ca}accession, Attributes: {}
#       Text: HMDB0004935
#     Tag: {http://www.hmdb.ca}accession, Attributes: {}
#       Text: HMDB0006703
#     Tag: {http://www.hmdb.ca}accession, Attributes: {}
#       Text: HMDB0006704
#     Tag: {http://www.hmdb.ca}accession, Attributes: {}
#       Text: HMDB04935
#     Tag: {http://www.hmdb.ca}accession, Attributes: {}
#       Text: HMDB06703
#     Tag: {http://www.hmdb.ca}accession, Attributes: {}
#       Text: HMDB06704
#   Tag: {http://www.hmdb.ca}name, Attributes: {}
#     Text: 1-Methylhistidine
#   Tag: {http://www.hmdb.ca}description, Attributes: {}
#     Text: 1-Methylhistidine, also known as 1-MHis or 1MH, belongs to the class of organic compounds known as histidine and derivatives. 1MH is also classified as a methylamino acid. Methylamino acids are primarily proteogenic amino acids (found in proteins) which have been methylated (in situ) on their side chains by various methyltransferase enzymes. Histidine can be methylated at either the N1 or N3 position of its imidazole ring, yielding the isomers 1-methylhistidine (1MH; also referred to as pi-methylhistidine) or 3-methylhistidine (3MH; tau-methylhistidine), respectively. There is considerable confusion with regard to the nomenclature of the methylated nitrogen atoms on the imidazole ring of histidine and other histidine-containing peptides such as anserine. In particular, older literature (mostly prior to the year 2000) designated anserine (Npi methylated) as beta-alanyl-N1-methyl-histidine, whereas according to standard IUPAC nomenclature, anserine is correctly named as beta-alanyl-N3-methyl-histidine. As a result, many papers published prior to the year 2000 incorrectly identified 1MH as a specific marker for dietary consumption or various pathophysiological effects when they really were referring to 3MH (PMID: 24137022).  Recent discoveries have shown that 1MH is produced in essentially all mammals (and other vertebrates) via the enzyme known as METTL9 (PMID: 33563959). METTL9 is a broad-specificity methyltransferase that mediates the formation of the majority of 1MH present in mammalian proteomes. METTL9-catalyzed methylation requires a His-x-His (HxH) motif, where "x" is a small amino acid. This HxH motif is found in a number of abundant mammalian proteins such as ARMC6, S100A9, and NDUFB3 (PMID: 33563959). Because of its abundance in many muscle-related proteins, 1MH has been found to be a good biomarker for the consumption of meat (PMID: 21527577). Dietary studies have shown that poultry consumption (p-trend = 0.0006) and chicken consumption (p-trend = 0.0003) are associated with increased levels of 1MH in human plasma (PMID: 30018457). The consumption of fish, especially salmon and cod, has also been shown to increase the levels of 1MH in serum and urine (PMID: 31401679). As a general rule, urinary 1MH is associated with white meat intake (p< 0.001), whereas urinary 3MH is associated with red meat intake (p< 0.001) (PMID: 34091671).
#   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: (2S)-2-Amino-3-(1-methyl-1H-imidazol-4-yl)propanoic acid
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: Pi-methylhistidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: (2S)-2-Amino-3-(1-methyl-1H-imidazol-4-yl)propanoate
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1 Methylhistidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1-Methyl histidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1-Methyl-histidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1-Methyl-L-histidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1-MHis
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1-N-Methyl-L-histidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: L-1-Methylhistidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: N1-Methyl-L-histidine
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1-Methylhistidine dihydrochloride
#     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#       Text: 1-Methylhistidine
#   Tag: {http://www.hmdb.ca}chemical_formula, Attributes: {}
#     Text: C7H11N3O2
#   Tag: {http://www.hmdb.ca}average_molecular_weight, Attributes: {}
#     Text: 169.1811
#   Tag: {http://www.hmdb.ca}monisotopic_molecular_weight, Attributes: {}
#     Text: 169.085126611
#   Tag: {http://www.hmdb.ca}iupac_name, Attributes: {}
#     Text: (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)propanoic acid
#   Tag: {http://www.hmdb.ca}traditional_iupac, Attributes: {}
#     Text: 1 methylhistidine
#   Tag: {http://www.hmdb.ca}cas_registry_number, Attributes: {}
#     Text: 332-80-9
#   Tag: {http://www.hmdb.ca}smiles, Attributes: {}
#     Text: CN1C=NC(C[C@H](N)C(O)=O)=C1
#   Tag: {http://www.hmdb.ca}inchi, Attributes: {}
#     Text: InChI=1S/C7H11N3O2/c1-10-3-5(9-4-10)2-6(8)7(11)12/h3-4,6H,2,8H2,1H3,(H,11,12)/t6-/m0/s1
#   Tag: {http://www.hmdb.ca}inchikey, Attributes: {}
#     Text: BRMWTNUJHUMWMS-LURJTMIESA-N
#   Tag: {http://www.hmdb.ca}taxonomy, Attributes: {}
#     Tag: {http://www.hmdb.ca}description, Attributes: {}
#       Text: belongs to the class of organic compounds known as histidine and derivatives. Histidine and derivatives are compounds containing cysteine or a derivative thereof resulting from reaction of cysteine at the amino group or the carboxy group, or from the replacement of any hydrogen of glycine by a heteroatom.
#     Tag: {http://www.hmdb.ca}direct_parent, Attributes: {}
#       Text: Histidine and derivatives
#     Tag: {http://www.hmdb.ca}kingdom, Attributes: {}
#       Text: Organic compounds
#     Tag: {http://www.hmdb.ca}super_class, Attributes: {}
#       Text: Organic acids and derivatives
#     Tag: {http://www.hmdb.ca}class, Attributes: {}
#       Text: Carboxylic acids and derivatives
#     Tag: {http://www.hmdb.ca}sub_class, Attributes: {}
#       Text: Amino acids, peptides, and analogues
#     Tag: {http://www.hmdb.ca}molecular_framework, Attributes: {}
#       Text: Aromatic heteromonocyclic compounds
#     Tag: {http://www.hmdb.ca}alternative_parents, Attributes: {}
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Amino acids
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Aralkylamines
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Azacyclic compounds
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Carbonyl compounds
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Carboxylic acids
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Heteroaromatic compounds
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Hydrocarbon derivatives
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Imidazolyl carboxylic acids and derivatives
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: L-alpha-amino acids
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Monoalkylamines
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Monocarboxylic acids and derivatives
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: N-substituted imidazoles
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Organic oxides
#       Tag: {http://www.hmdb.ca}alternative_parent, Attributes: {}
#         Text: Organopnictogen compounds
#     Tag: {http://www.hmdb.ca}substituents, Attributes: {}
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Alpha-amino acid
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Amine
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Amino acid
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Aralkylamine
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Aromatic heteromonocyclic compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Azacycle
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Azole
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Carbonyl group
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Carboxylic acid
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Heteroaromatic compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Histidine or derivatives
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Hydrocarbon derivative
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Imidazole
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Imidazolyl carboxylic acid derivative
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: L-alpha-amino acid
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Monocarboxylic acid or derivatives
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: N-substituted imidazole
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Organic nitrogen compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Organic oxide
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Organic oxygen compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Organoheterocyclic compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Organonitrogen compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Organooxygen compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Organopnictogen compound
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Primary aliphatic amine
#       Tag: {http://www.hmdb.ca}substituent, Attributes: {}
#         Text: Primary amine
#     Tag: {http://www.hmdb.ca}external_descriptors, Attributes: {}
#       Tag: {http://www.hmdb.ca}external_descriptor, Attributes: {}
#         Text: L-histidine derivative
#       Tag: {http://www.hmdb.ca}external_descriptor, Attributes: {}
#         Text: non-proteinogenic L-alpha-amino acid
#   Tag: {http://www.hmdb.ca}ontology, Attributes: {}
#     Tag: {http://www.hmdb.ca}root, Attributes: {}
#       Tag: {http://www.hmdb.ca}term, Attributes: {}
#         Text: Physiological effect
#       Tag: {http://www.hmdb.ca}definition, Attributes: {}
#         Text: The effect on an organism physiology, resulting from its exposure to a chemical.
#       Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#       Tag: {http://www.hmdb.ca}level, Attributes: {}
#         Text: 1
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: parent
#       Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#         Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#           Tag: {http://www.hmdb.ca}term, Attributes: {}
#             Text: Health effect
#           Tag: {http://www.hmdb.ca}definition, Attributes: {}
#             Text: A health condition or observation associated with a stimuli or with a biological activity of a chemical.
#           Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#             Text: 7693
#           Tag: {http://www.hmdb.ca}level, Attributes: {}
#             Text: 2
#           Tag: {http://www.hmdb.ca}type, Attributes: {}
#             Text: parent
#           Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#           Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#             Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#               Tag: {http://www.hmdb.ca}term, Attributes: {}
#                 Text: Health condition
#               Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                 Text: A health effect that consists on short or long-term disease, condition, disorder, syndrome or constant abnormality.
#               Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                 Text: 7694
#               Tag: {http://www.hmdb.ca}level, Attributes: {}
#                 Text: 3
#               Tag: {http://www.hmdb.ca}type, Attributes: {}
#                 Text: parent
#               Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#               Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Kidney disease
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: A urinary system disease that is located in the kidney. (do).
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7695
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Renal disease
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Nephropathy
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Diabetes mellitus type 2
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7695
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Non-insulin-dependent diabetes mellitus
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Niddm
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Adult-onset diabetes
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Metabolism and nutrition disorders
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: A group of disorders, inherited or not, that result in a metabolic malfunction.
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7695
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: parent
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                   Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                     Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                       Tag: {http://www.hmdb.ca}term, Attributes: {}
#                         Text: Obesity
#                       Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                         Text: A disorder characterized by having a high amount of body fat. (nci ctcae).
#                       Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                         Text: 7708
#                       Tag: {http://www.hmdb.ca}level, Attributes: {}
#                         Text: 5
#                       Tag: {http://www.hmdb.ca}type, Attributes: {}
#                         Text: child
#                       Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#     Tag: {http://www.hmdb.ca}root, Attributes: {}
#       Tag: {http://www.hmdb.ca}term, Attributes: {}
#         Text: Disposition
#       Tag: {http://www.hmdb.ca}definition, Attributes: {}
#         Text: A concept that describes the origin of a chemical, its location within an organism, or its route of exposure.
#       Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#       Tag: {http://www.hmdb.ca}level, Attributes: {}
#         Text: 1
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: parent
#       Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#         Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#           Tag: {http://www.hmdb.ca}term, Attributes: {}
#             Text: Source
#           Tag: {http://www.hmdb.ca}definition, Attributes: {}
#             Text: Natural or synthetic origin of a chemical.
#           Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#             Text: 7724
#           Tag: {http://www.hmdb.ca}level, Attributes: {}
#             Text: 2
#           Tag: {http://www.hmdb.ca}type, Attributes: {}
#             Text: parent
#           Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#           Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#             Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#               Tag: {http://www.hmdb.ca}term, Attributes: {}
#                 Text: Endogenous
#               Tag: {http://www.hmdb.ca}definition, Attributes: {}
#               Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                 Text: 7735
#               Tag: {http://www.hmdb.ca}level, Attributes: {}
#                 Text: 3
#               Tag: {http://www.hmdb.ca}type, Attributes: {}
#                 Text: child
#               Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#         Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#           Tag: {http://www.hmdb.ca}term, Attributes: {}
#             Text: Biological location
#           Tag: {http://www.hmdb.ca}definition, Attributes: {}
#             Text: The physiological origin within an organism, including anatomical compnents, biofluids and excreta.
#           Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#             Text: 7724
#           Tag: {http://www.hmdb.ca}level, Attributes: {}
#             Text: 2
#           Tag: {http://www.hmdb.ca}type, Attributes: {}
#             Text: parent
#           Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#           Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#             Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#               Tag: {http://www.hmdb.ca}term, Attributes: {}
#                 Text: Tissue and substructures
#               Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                 Text: An anatomical organizational level including multiple cells yet not comprising a complete organ .
#               Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                 Text: 7725
#               Tag: {http://www.hmdb.ca}level, Attributes: {}
#                 Text: 3
#               Tag: {http://www.hmdb.ca}type, Attributes: {}
#                 Text: parent
#               Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#               Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Muscle
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: A fibrous soft tissue with the ability to contract to produce force and motion. (nci).
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7729
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Skeletal muscle
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: Striated muscles that are under voluntary control of the organism. they are connected at either or both ends to a bone and are utilized for locomotion and other movements. (nci).
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7729
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Striated muscle
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Placenta
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: An organ present in some vertebrates during embryonic gestation that surrounds the fetus and provides it with nutrients and oxygen, facilitates gas and waste exchange between the fetus and mother, and provides parasitic cloaking from the mother's immune system by excretion of neurokinin b. (nci).
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7729
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#             Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#               Tag: {http://www.hmdb.ca}term, Attributes: {}
#                 Text: Biofluid and excreta
#               Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                 Text: A liquid, semi-solid or solid material originating in the body.
#               Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                 Text: 7725
#               Tag: {http://www.hmdb.ca}level, Attributes: {}
#                 Text: 3
#               Tag: {http://www.hmdb.ca}type, Attributes: {}
#                 Text: parent
#               Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#               Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Saliva
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: The watery fluid in the mouth made by the salivary glands. saliva moistens food to help digestion and it helps protect the mouth against infections. (nci).
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7731
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Feces
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: The material discharged from the bowel during defecation. It consists of undigested food, intestinal mucus, epithelial cells, and bacteria.
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7731
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Fecal
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Stool
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Faecal
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Faeces
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Urine
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: Excretion in liquid state processed by the kidney.
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7731
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Blood
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: A liquid tissue with the primary function of transporting oxygen and carbon dioxide (nci). it supplies the tissues with nutrients, removes waste products, and contains various components of the immune system defending the body against infection.
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7731
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Cerebrospinal fluid
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: The fluid that is contained within the brain ventricles, the subarachnoid space and the central canal of the spinal cord. (nci).
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7731
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Csf
#             Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#               Tag: {http://www.hmdb.ca}term, Attributes: {}
#                 Text: Subcellular
#               Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                 Text: An anatomical organizational level including a component within a biological cell .
#               Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                 Text: 7725
#               Tag: {http://www.hmdb.ca}level, Attributes: {}
#                 Text: 3
#               Tag: {http://www.hmdb.ca}type, Attributes: {}
#                 Text: parent
#               Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#               Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Cytoplasm
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: The portion of the cell contained within the plasma membrane but excluding the nucleus.
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7730
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                     Tag: {http://www.hmdb.ca}synonym, Attributes: {}
#                       Text: Cytoplasma
#     Tag: {http://www.hmdb.ca}root, Attributes: {}
#       Tag: {http://www.hmdb.ca}term, Attributes: {}
#         Text: Process
#       Tag: {http://www.hmdb.ca}definition, Attributes: {}
#         Text: Biological or chemical events, or a series thereof, leading to a known function or end-product.
#       Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#       Tag: {http://www.hmdb.ca}level, Attributes: {}
#         Text: 1
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: parent
#       Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#         Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#           Tag: {http://www.hmdb.ca}term, Attributes: {}
#             Text: Naturally occurring process
#           Tag: {http://www.hmdb.ca}definition, Attributes: {}
#             Text: Naturally-occurring molecular events or a series thereof, leading to a known function or end-product.
#           Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#             Text: 7659
#           Tag: {http://www.hmdb.ca}level, Attributes: {}
#             Text: 2
#           Tag: {http://www.hmdb.ca}type, Attributes: {}
#             Text: parent
#           Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#           Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#             Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#               Tag: {http://www.hmdb.ca}term, Attributes: {}
#                 Text: Biological process
#               Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                 Text: Biological or chemical events or a series thereof, leading to a known function or end-product within an organism.
#               Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                 Text: 7660
#               Tag: {http://www.hmdb.ca}level, Attributes: {}
#                 Text: 3
#               Tag: {http://www.hmdb.ca}type, Attributes: {}
#                 Text: parent
#               Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#               Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Biochemical pathway
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                     Text: A linked series of chemical reactions that occur in a defined order within or between organism cells, and lead to a known function or end product.
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7661
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: parent
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#                   Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                     Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                       Tag: {http://www.hmdb.ca}term, Attributes: {}
#                         Text: Histidine Metabolism
#                       Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                         Text: after reaching several years of age, humans begin to synthesize it (most likely in the intestinal micrflora) and it thus becomes a non-essential amino acid. humans can obtain histidine through the breakdown of carnosine (a dipeptide containing histidine and beta-alanine) via the action of carnosine dipeptidase.
#                       Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                         Text: 7662
#                       Tag: {http://www.hmdb.ca}level, Attributes: {}
#                         Text: 5
#                       Tag: {http://www.hmdb.ca}type, Attributes: {}
#                         Text: child
#                       Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#     Tag: {http://www.hmdb.ca}root, Attributes: {}
#       Tag: {http://www.hmdb.ca}term, Attributes: {}
#         Text: Role
#       Tag: {http://www.hmdb.ca}definition, Attributes: {}
#         Text: The purpose or function assumed by a chemical, either naturally or as intended by humans .
#       Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#       Tag: {http://www.hmdb.ca}level, Attributes: {}
#         Text: 1
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: parent
#       Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#         Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#           Tag: {http://www.hmdb.ca}term, Attributes: {}
#             Text: Industrial application
#           Tag: {http://www.hmdb.ca}definition, Attributes: {}
#             Text: The assumed function of a chemical utilized by human.
#           Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#             Text: 7671
#           Tag: {http://www.hmdb.ca}level, Attributes: {}
#             Text: 2
#           Tag: {http://www.hmdb.ca}type, Attributes: {}
#             Text: parent
#           Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#           Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#             Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#               Tag: {http://www.hmdb.ca}term, Attributes: {}
#                 Text: Pharmaceutical industry
#               Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                 Text: A pharmacologic activity for which a chemical substance is utilized owing to its biological role.
#               Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                 Text: 7678
#               Tag: {http://www.hmdb.ca}level, Attributes: {}
#                 Text: 3
#               Tag: {http://www.hmdb.ca}type, Attributes: {}
#                 Text: parent
#               Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#               Tag: {http://www.hmdb.ca}descendants, Attributes: {}
#                 Tag: {http://www.hmdb.ca}descendant, Attributes: {}
#                   Tag: {http://www.hmdb.ca}term, Attributes: {}
#                     Text: Pharmaceutical
#                   Tag: {http://www.hmdb.ca}definition, Attributes: {}
#                   Tag: {http://www.hmdb.ca}parent_id, Attributes: {}
#                     Text: 7679
#                   Tag: {http://www.hmdb.ca}level, Attributes: {}
#                     Text: 4
#                   Tag: {http://www.hmdb.ca}type, Attributes: {}
#                     Text: child
#                   Tag: {http://www.hmdb.ca}synonyms, Attributes: {}
#   Tag: {http://www.hmdb.ca}state, Attributes: {}
#     Text: Solid
#   Tag: {http://www.hmdb.ca}experimental_properties, Attributes: {}
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: water_solubility
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 200 g/kg
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: http://download.cappchem.com/data/Properties-of-Amino-Acids.pdf
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: melting_point
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 249 °C
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: http://download.cappchem.com/data/Properties-of-Amino-Acids.pdf
#   Tag: {http://www.hmdb.ca}predicted_properties, Attributes: {}
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: logp
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: -2.95
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ALOGPS
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: logs
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: -1.39
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ALOGPS
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: solubility
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 6.93 g/L
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ALOGPS
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: logp
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: -3.1
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: pka_strongest_acidic
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 1.96
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: pka_strongest_basic
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 9.25
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: iupac
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)propanoic acid
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: average_mass
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 169.1811
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: mono_mass
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 169.085126611
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: smiles
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: CN1C=NC(C[C@H](N)C(O)=O)=C1
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: formula
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: C7H11N3O2
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: inchi
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: InChI=1S/C7H11N3O2/c1-10-3-5(9-4-10)2-6(8)7(11)12/h3-4,6H,2,8H2,1H3,(H,11,12)/t6-/m0/s1
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: inchikey
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: BRMWTNUJHUMWMS-LURJTMIESA-N
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: polar_surface_area
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 81.14
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: refractivity
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 42.39
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: polarizability
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 17.11
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: rotatable_bond_count
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 3
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: acceptor_count
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 4
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: donor_count
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 2
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: physiological_charge
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 0
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: formal_charge
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 0
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: number_of_rings
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: 1
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: bioavailability
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: Yes
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: rule_of_five
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: Yes
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: ghose_filter
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: No
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: veber_rule
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: No
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#     Tag: {http://www.hmdb.ca}property, Attributes: {}
#       Tag: {http://www.hmdb.ca}kind, Attributes: {}
#         Text: mddr_like_rule
#       Tag: {http://www.hmdb.ca}value, Attributes: {}
#         Text: No
#       Tag: {http://www.hmdb.ca}source, Attributes: {}
#         Text: ChemAxon
#   Tag: {http://www.hmdb.ca}spectra, Attributes: {}
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrTwoD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 915
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 1022
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5292
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5293
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5294
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5295
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5296
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5297
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5298
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5299
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5300
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5301
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5302
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5303
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5304
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5305
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5306
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5307
#     Tag: {http://www.hmdb.ca}spectrum, Attributes: {}
#       Tag: {http://www.hmdb.ca}type, Attributes: {}
#         Text: Specdb::NmrOneD
#       Tag: {http://www.hmdb.ca}spectrum_id, Attributes: {}
#         Text: 5308
# ...
#             Text: 2226555
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Riemersma M, Hazebroek MR, Helderman-van den Enden ATJM, Salomons GS, Ferdinandusse S, Brouwers MCGJ, van der Ploeg L, Heymans S, Glatz JFC, van den Wijngaard A, Krapels IPC, Bierau J, Brunner HG: Propionic acidemia as a cause of adult-onset dilated cardiomyopathy. Eur J Hum Genet. 2017 Nov;25(11):1195-1201. doi: 10.1038/ejhg.2017.127. Epub 2017 Aug 30.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 28853722
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: MetaGene: Metabolic & Genetic Information Center (MIC: http://www.metagene.de)
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#     Tag: {http://www.hmdb.ca}disease, Attributes: {}
#       Tag: {http://www.hmdb.ca}name, Attributes: {}
#         Text: Maple syrup urine disease
#       Tag: {http://www.hmdb.ca}omim_id, Attributes: {}
#         Text: 248600
#       Tag: {http://www.hmdb.ca}references, Attributes: {}
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Deng C, Shang C, Hu Y, Zhang X: Rapid diagnosis of phenylketonuria and other aminoacidemias by quantitative analysis of amino acids in neonatal blood spots by gas chromatography-mass spectrometry. J Chromatogr B Analyt Technol Biomed Life Sci. 2002 Jul 25;775(1):115-20.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 12101068
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Schadewaldt P, Bodner-Leidecker A, Hammen HW, Wendel U: Significance of L-alloisoleucine in plasma for diagnosis of maple syrup urine disease. Clin Chem. 1999 Oct;45(10):1734-40.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 10508118
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Schadewaldt P, Hammen HW, Ott AC, Wendel U: Renal clearance of branched-chain L-amino and 2-oxo acids in maple syrup urine disease. J Inherit Metab Dis. 1999 Aug;22(6):706-22.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 10472531
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Gronwald W, Klein MS, Kaspar H, Fagerer SR, Nurnberger N, Dettmer K, Bertsch T, Oefner PJ: Urinary metabolite quantification employing 2D NMR spectroscopy. Anal Chem. 2008 Dec 1;80(23):9288-97. doi: 10.1021/ac801627c.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 19551947
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Kumps A, Duez P, Mardens Y: Metabolic, nutritional, iatrogenic, and artifactual sources of urinary organic acids: a comprehensive table. Clin Chem. 2002 May;48(5):708-17.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 11978597
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Podebrad F, Heil M, Reichert S, Mosandl A, Sewell AC, Bohles H: 4,5-dimethyl-3-hydroxy-2[5H]-furanone (sotolone)--the odour of maple syrup urine disease. J Inherit Metab Dis. 1999 Apr;22(2):107-14.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 10234605
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Shigematsu Y, Kikuchi K, Momoi T, Sudo M, Kikawa Y, Nosaka K, Kuriyama M, Haruki S, Sanada K, Hamano N, et al.: Organic acids and branched-chain amino acids in body fluids before and after multiple exchange transfusions in maple syrup urine disease. J Inherit Metab Dis. 1983;6(4):183-9.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 6422161
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Yunus ZM, Kamaludin DA, Mamat M, Choy YS, Ngu L: Clinical and biochemical profiles of maple syrup urine disease in malaysian children. JIMD Rep. 2012;5:99-107. doi: 10.1007/8904_2011_105. Epub 2011 Dec 11.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 23430924
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Barschak AG, Marchesan C, Sitta A, Deon M, Giugliani R, Wajner M, Vargas CR: Maple syrup urine disease in treated patients: biochemical and oxidative stress profiles. Clin Biochem. 2008 Mar;41(4-5):317-24. Epub 2007 Dec 5.
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#             Text: 18088602
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: MetaGene: Metabolic & Genetic Information Center (MIC: http://www.metagene.de)
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Peritoneal dialysis in maple-syrup-urine disease: Studies on branched-chain amino and keto acids. Eur J Pediatr (1980) 134: 57. https://doi.org/10.1007/BF00442404
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#     Tag: {http://www.hmdb.ca}disease, Attributes: {}
#       Tag: {http://www.hmdb.ca}name, Attributes: {}
#         Text: Eosinophilic esophagitis
#       Tag: {http://www.hmdb.ca}omim_id, Attributes: {}
#         Text: 610247
#       Tag: {http://www.hmdb.ca}references, Attributes: {}
#         Tag: {http://www.hmdb.ca}reference, Attributes: {}
#           Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#             Text: Mordechai, Hien, and David S. Wishart
#           Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#   Tag: {http://www.hmdb.ca}chemspider_id, Attributes: {}
#     Text: 83153
#   Tag: {http://www.hmdb.ca}drugbank_id, Attributes: {}
#     Text: DB04151
#   Tag: {http://www.hmdb.ca}foodb_id, Attributes: {}
#     Text: FDB093588
#   Tag: {http://www.hmdb.ca}pubchem_compound_id, Attributes: {}
#     Text: 92105
#   Tag: {http://www.hmdb.ca}pdb_id, Attributes: {}
#   Tag: {http://www.hmdb.ca}chebi_id, Attributes: {}
#     Text: 50599
#   Tag: {http://www.hmdb.ca}phenol_explorer_compound_id, Attributes: {}
#   Tag: {http://www.hmdb.ca}knapsack_id, Attributes: {}
#     Text: C00052105
#   Tag: {http://www.hmdb.ca}kegg_id, Attributes: {}
#     Text: C01152
#   Tag: {http://www.hmdb.ca}biocyc_id, Attributes: {}
#   Tag: {http://www.hmdb.ca}bigg_id, Attributes: {}
#   Tag: {http://www.hmdb.ca}wikipedia_id, Attributes: {}
#     Text: Methylhistidine
#   Tag: {http://www.hmdb.ca}metlin_id, Attributes: {}
#     Text: 3741
#   Tag: {http://www.hmdb.ca}vmh_id, Attributes: {}
#   Tag: {http://www.hmdb.ca}fbonto_id, Attributes: {}
#   Tag: {http://www.hmdb.ca}synthesis_reference, Attributes: {}
#     Text: Jain, Rahul; Cohen, Louis A. Regiospecific alkylation of histidine and histamine at N-1 (t).Tetrahedron  (1996),  52(15),  5363-70.
#   Tag: {http://www.hmdb.ca}general_references, Attributes: {}
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Colombani PC, Kovacs E, Frey-Rindova P, Frey W, Langhans W, Arnold M, Wenk C: Metabolic effects of a protein-supplemented carbohydrate drink in marathon runners. Int J Sport Nutr. 1999 Jun;9(2):181-201.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 10362454
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Nicholson JK, Foxall PJ, Spraul M, Farrant RD, Lindon JC: 750 MHz 1H and 1H-13C NMR spectroscopy of human blood plasma. Anal Chem. 1995 Mar 1;67(5):793-811.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 7762816
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Myint T, Fraser GE, Lindsted KD, Knutsen SF, Hubbard RW, Bennett HW: Urinary 1-methylhistidine is a marker of meat consumption in Black and in White California Seventh-day Adventists. Am J Epidemiol. 2000 Oct 15;152(8):752-5.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 11052553
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Giesecke K, Magnusson I, Ahlberg M, Hagenfeldt L, Wahren J: Protein and amino acid metabolism during early starvation as reflected by excretion of urea and methylhistidines. Metabolism. 1989 Dec;38(12):1196-200.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 2593832
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Vranic L, Granic P, Rajic Z: Basic amino acid in the pathogenesis of caries. Acta Stomatol Croat. 1991;25(2):71-6.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 1819935
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Sjolin J, Stjernstrom H, Henneberg S, Hambraeus L, Friman G: Evaluation of urinary 3-methylhistidine excretion in infection by measurements of 1-methylhistidine and the creatinine ratios. Am J Clin Nutr. 1989 Jan;49(1):62-70.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 2912013
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: COCKS DH, DENNIS PO, NELSON TH: ISOLATION OF 3-METHYL HISTIDINE FROM WHALEMEAT EXTRACT AND THE PREPARATION OF SOME DERIVATIVES. Nature. 1964 Apr 11;202:184-5.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 14156296
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Dohm GL, Williams RT, Kasperek GJ, van Rij AM: Increased excretion of urea and N tau -methylhistidine by rats and humans after a bout of exercise. J Appl Physiol Respir Environ Exerc Physiol. 1982 Jan;52(1):27-33.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 7061274
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Garlick PJ, McNurlan MA, Bark T, Lang CH, Gelato MC: Hormonal regulation of protein metabolism in relation to nutrition and disease. J Nutr. 1998 Feb;128(2 Suppl):356S-359S.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 9478024
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Tuma P, Samcova E, Balinova P: Determination of 3-methylhistidine and 1-methylhistidine in untreated urine samples by capillary electrophoresis. J Chromatogr B Analyt Technol Biomed Life Sci. 2005 Jul 5;821(1):53-9.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 15899597
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Dunnett M, Harris RC: High-performance liquid chromatographic determination of imidazole dipeptides, histidine, 1-methylhistidine and 3-methylhistidine in equine and camel muscle and individual muscle fibres. J Chromatogr B Biomed Sci Appl. 1997 Jan 10;688(1):47-55.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 9029312
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Betto P, Ricciarello G, Pichini S, Dello Strologo L, Rizzoni G: High-performance liquid chromatography-electrochemical detection of 3-methylhistidine in human urine. J Chromatogr. 1992 Dec 23;584(2):256-60.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 1484110
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Elshenawy S, Pinney SE, Stuart T, Doulias PT, Zura G, Parry S, Elovitz MA, Bennett MJ, Bansal A, Strauss JF 3rd, Ischiropoulos H, Simmons RA: The Metabolomic Signature of the Placenta in Spontaneous Preterm Birth. Int J Mol Sci. 2020 Feb 4;21(3). pii: ijms21031043. doi: 10.3390/ijms21031043.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 32033212
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Boldyrev AA, Aldini G, Derave W: Physiology and pathophysiology of carnosine. Physiol Rev. 2013 Oct;93(4):1803-45. doi: 10.1152/physrev.00039.2012.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 24137022
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Davydova E, Shimazu T, Schuhmacher MK, Jakobsson ME, Willemen HLDM, Liu T, Moen A, Ho AYY, Malecki J, Schroer L, Pinto R, Suzuki T, Gronsberg IA, Sohtome Y, Akakabe M, Weirich S, Kikuchi M, Olsen JV, Dohmae N, Umehara T, Sodeoka M, Siino V, McDonough MA, Eijkelkamp N, Schofield CJ, Jeltsch A, Shinkai Y, Falnes PO: The methyltransferase METTL9 mediates pervasive 1-methylhistidine modification in mammalian proteomes. Nat Commun. 2021 Feb 9;12(1):891. doi: 10.1038/s41467-020-20670-7.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 33563959
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Cross AJ, Major JM, Sinha R: Urinary biomarkers of meat consumption. Cancer Epidemiol Biomarkers Prev. 2011 Jun;20(6):1107-11. doi: 10.1158/1055-9965.EPI-11-0048. Epub 2011 Apr 28.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 21527577
#     Tag: {http://www.hmdb.ca}reference, Attributes: {}
#       Tag: {http://www.hmdb.ca}reference_text, Attributes: {}
#         Text: Mitry P, Wawro N, Rohrmann S, Giesbertz P, Daniel H, Linseisen J: Plasma concentrations of anserine, carnosine and pi-methylhistidine as biomarkers of habitual meat consumption. Eur J Clin Nutr. 2019 May;73(5):692-702. doi: 10.1038/s41430-018-0248-1. Epub 2018 Jul 17.
#       Tag: {http://www.hmdb.ca}pubmed_id, Attributes: {}
#         Text: 30018457
#   Tag: {http://www.hmdb.ca}protein_associations, Attributes: {}
#     Tag: {http://www.hmdb.ca}protein, Attributes: {}
#       Tag: {http://www.hmdb.ca}protein_accession, Attributes: {}
#         Text: HMDBP00473
#       Tag: {http://www.hmdb.ca}name, Attributes: {}
#         Text: Beta-Ala-His dipeptidase
#       Tag: {http://www.hmdb.ca}uniprot_id, Attributes: {}
#         Text: Q96KN2
#       Tag: {http://www.hmdb.ca}gene_name, Attributes: {}
#         Text: CNDP1
#       Tag: {http://www.hmdb.ca}protein_type, Attributes: {}
#         Text: Unknown
#     Tag: {http://www.hmdb.ca}protein, Attributes: {}
#       Tag: {http://www.hmdb.ca}protein_accession, Attributes: {}
#         Text: HMDBP00474
#       Tag: {http://www.hmdb.ca}name, Attributes: {}
#         Text: Protein arginine N-methyltransferase 3
#       Tag: {http://www.hmdb.ca}uniprot_id, Attributes: {}
#         Text: O60678
#       Tag: {http://www.hmdb.ca}gene_name, Attributes: {}
#         Text: PRMT3
#       Tag: {http://www.hmdb.ca}protein_type, Attributes: {}
#         Text: Unknown

# %%
import pandas as pd
# List to hold metabolite data
# Function to extract text from an XML element, if it exists
def get_text(element, tag, namespace):
    child = element.find(f'ns:{tag}', namespace)
    return child.text if child is not None else None

# Function to extract a list of texts from XML elements, if they exist
def get_text_list(element, tag, namespace):
    children = element.findall(f'ns:{tag}', namespace)
    return [child.text for child in children] if children is not None else None

data = []
namespace = {'ns': 'http://www.hmdb.ca'}

# Iterate through each metabolite
for metabolite in root.findall('ns:metabolite', namespace):
    # Extract required elements
    accession = get_text(metabolite, 'accession', namespace)
    secondary_accessions = get_text_list(metabolite.find('ns:secondary_accessions', namespace), 'accession', namespace)
    name = get_text(metabolite, 'name', namespace)
    synonyms = get_text_list(metabolite.find('ns:synonyms', namespace), 'synonym', namespace)
    chemical_formula = get_text(metabolite, 'chemical_formula', namespace)
    iupac_name = get_text(metabolite, 'iupac_name', namespace)
    cas_registry_number = get_text(metabolite, 'cas_registry_number', namespace)
    smiles = get_text(metabolite, 'smiles', namespace)
    inchi = get_text(metabolite, 'inchi', namespace)
    inchikey = get_text(metabolite, 'inchikey', namespace)
    description = get_text(metabolite, 'description', namespace)
    monisotopic_molecular_weight = get_text(metabolite, 'monisotopic_molecular_weight', namespace)
    average_molecular_weight = get_text(metabolite, 'average_molecular_weight', namespace)
    
    # Append the metabolite data to the list
    data.append([accession, secondary_accessions, name, synonyms, chemical_formula, iupac_name, cas_registry_number, smiles, inchi, inchikey, monisotopic_molecular_weight, average_molecular_weight, description])

# Create a DataFrame
columns = ['accession', 'secondary_accessions', 'name', 'synonyms', 'chemical_formula', 'iupac_name', 'cas_registry_number', 'smiles', 'inchi', 'inchikey', 'monisotopic_molecular_weight', 'average_molecular_weight', 'description']
df = pd.DataFrame(data, columns=columns)

# Display the DataFrame
df.head()

# Save the DataFrame to a CSV file if needed
#df.to_csv('metabolites.csv', index=False)
#df.drop('description').to_csv('metabolites_no_description.csv', index=False)
# Out:
#      accession                               secondary_accessions  \
# 0  HMDB0000001  [HMDB00001, HMDB0004935, HMDB0006703, HMDB0006...
# 1  HMDB0000002                [HMDB00002, HMDB0060172, HMDB60172]
# 2  HMDB0000005                [HMDB00005, HMDB0006544, HMDB06544]
# 3  HMDB0000008                                        [HMDB00008]
# 4  HMDB0000010  [HMDB00010, HMDB0004990, HMDB0004991, HMDB0499...
#
#                     name                                           synonyms  \
# 0      1-Methylhistidine  [(2S)-2-Amino-3-(1-methyl-1H-imidazol-4-yl)pro...
# 1     1,3-Diaminopropane  [1,3-Propanediamine, 1,3-Propylenediamine, Pro...
# 2     2-Ketobutyric acid  [2-Ketobutanoic acid, 2-Oxobutyric acid, 3-Met...
# 3  2-Hydroxybutyric acid  [(S)-2-Hydroxybutanoic acid, 2-Hydroxybutyrate...
# 4       2-Methoxyestrone  [2-(8S,9S,13S,14S)-3-Hydroxy-2-methoxy-13-meth...
#
#   chemical_formula                                         iupac_name  \
# 0        C7H11N3O2  (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)prop...
# 1          C3H10N2                                propane-1,3-diamine
# 2           C4H6O3                                 2-oxobutanoic acid
# 3           C4H8O3                        (2S)-2-hydroxybutanoic acid
# 4         C19H24O3  (1S,10R,11S,15S)-5-hydroxy-4-methoxy-15-methyl...
#
#   cas_registry_number                                             smiles  \
# 0            332-80-9                        CN1C=NC(C[C@H](N)C(O)=O)=C1
# 1            109-76-2                                              NCCCN
# 2            600-18-0                                      CCC(=O)C(O)=O
# 3           3347-90-8                                   CC[C@H](O)C(O)=O
# 4            362-08-3  [H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[...
#
#                                                inchi  \
# 0  InChI=1S/C7H11N3O2/c1-10-3-5(9-4-10)2-6(8)7(11...
# 1                 InChI=1S/C3H10N2/c4-2-1-3-5/h1-5H2
# 2    InChI=1S/C4H6O3/c1-2-3(5)4(6)7/h2H2,1H3,(H,6,7)
# 3  InChI=1S/C4H8O3/c1-2-3(5)4(6)7/h3,5H,2H2,1H3,(...
# 4  InChI=1S/C19H24O3/c1-19-8-7-12-13(15(19)5-6-18...
#
#                       inchikey monisotopic_molecular_weight  \
# 0  BRMWTNUJHUMWMS-LURJTMIESA-N                169.085126611
# 1  XFNJVJPLKCPIBV-UHFFFAOYSA-N                  74.08439833
# 2  TYEYBOSBBBHJIV-UHFFFAOYSA-N                102.031694058
# 3  AFENDNXGAFYKQO-VKHMYHEASA-N                104.047344118
# 4  WHEUWNKSCXYKBU-QPWUGHHJSA-N                300.172544634
#
#   average_molecular_weight                                        description
# 0                 169.1811  1-Methylhistidine, also known as 1-MHis or 1MH...
# 1                  74.1249  1,3-Diaminopropane, also known as DAP or trime...
# 2                 102.0886  2-Ketobutyric acid, also known as alpha-ketobu...
# 3                  104.105  2-Hydroxybutyric acid (CAS: 600-15-7), also kn...
# 4                 300.3921  2-Methoxyestrone (or 2-ME1) belongs to the cla...

# %%
import os

def is_1h_file(path):
    if os.path.isfile(path):
        with open(path) as f:
            first_line = f.readline()
            return "_13C_" not in first_line and "ADDRESS" not in first_line
    return False

def list_files(folder_path):
    try:
        # Get all entries in the folder
        entries = os.listdir(folder_path)
        # Filter out only files
        files = [f for f in entries if is_1h_file(os.path.join(folder_path, f))]
        return files
    except FileNotFoundError:
        print(f"Folder not found: {folder_path}")
        return []
    except PermissionError:
        print(f"Permission denied: {folder_path}")
        return []

spectra_files = list_files('hmdb_urine/hmdb_nmr_peak_lists')
print(len(spectra_files))
# Out:
# 1786

# %%
def create_dataframe(file_list):
    # List to hold the data for each file
    data = []

    for file_name in file_list:
        # Split the file name by "_" and take the first part as accession
        tokens  = file_name.split('_')
        # Append the data as a tuple (accession, file_name)
        data.append((tokens[0], file_name, tokens[1]))

    # Create the DataFrame
    df = pd.DataFrame(data, columns=['accession', 'file_name', 'dim'])

    return df

df_files = create_dataframe(spectra_files)

#Filter out only 1d files
df_files = df_files[df_files['dim'] == 'nmroned']
df_files.head()
# Out:
#       accession                             file_name      dim
# 4   HMDB0003072  HMDB0003072_nmroned_5251_2734492.txt  nmroned
# 7   HMDB0000176    HMDB0000176_nmroned_1144_28428.txt  nmroned
# 9   HMDB0002873    HMDB0002873_nmroned_1910_33109.txt  nmroned
# 11  HMDB0000622    HMDB0000622_nmroned_1440_29992.txt  nmroned
# 12  HMDB0000548    HMDB0000548_nmroned_1415_29734.txt  nmroned

# %%
df = df.join(df_files.set_index('accession'), on='accession', how='left')
df = df.dropna(subset=['file_name'])
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#      accession                               secondary_accessions  \
# 0  HMDB0000001  [HMDB00001, HMDB0004935, HMDB0006703, HMDB0006...
# 1  HMDB0000002                [HMDB00002, HMDB0060172, HMDB60172]
# 2  HMDB0000005                [HMDB00005, HMDB0006544, HMDB06544]
# 3  HMDB0000008                                        [HMDB00008]
# 4  HMDB0000010  [HMDB00010, HMDB0004990, HMDB0004991, HMDB0499...
#
#                     name                                           synonyms  \
# 0      1-Methylhistidine  [(2S)-2-Amino-3-(1-methyl-1H-imidazol-4-yl)pro...
# 1     1,3-Diaminopropane  [1,3-Propanediamine, 1,3-Propylenediamine, Pro...
# 2     2-Ketobutyric acid  [2-Ketobutanoic acid, 2-Oxobutyric acid, 3-Met...
# 3  2-Hydroxybutyric acid  [(S)-2-Hydroxybutanoic acid, 2-Hydroxybutyrate...
# 4       2-Methoxyestrone  [2-(8S,9S,13S,14S)-3-Hydroxy-2-methoxy-13-meth...
#
#   chemical_formula                                         iupac_name  \
# 0        C7H11N3O2  (2S)-2-amino-3-(1-methyl-1H-imidazol-4-yl)prop...
# 1          C3H10N2                                propane-1,3-diamine
# 2           C4H6O3                                 2-oxobutanoic acid
# 3           C4H8O3                        (2S)-2-hydroxybutanoic acid
# 4         C19H24O3  (1S,10R,11S,15S)-5-hydroxy-4-methoxy-15-methyl...
#
#   cas_registry_number                                             smiles  \
# 0            332-80-9                        CN1C=NC(C[C@H](N)C(O)=O)=C1
# 1            109-76-2                                              NCCCN
# 2            600-18-0                                      CCC(=O)C(O)=O
# 3           3347-90-8                                   CC[C@H](O)C(O)=O
# 4            362-08-3  [H][C@@]12CCC(=O)[C@@]1(C)CC[C@]1([H])C3=C(CC[...
#
#                                                inchi  \
# 0  InChI=1S/C7H11N3O2/c1-10-3-5(9-4-10)2-6(8)7(11...
# 1                 InChI=1S/C3H10N2/c4-2-1-3-5/h1-5H2
# 2    InChI=1S/C4H6O3/c1-2-3(5)4(6)7/h2H2,1H3,(H,6,7)
# 3  InChI=1S/C4H8O3/c1-2-3(5)4(6)7/h3,5H,2H2,1H3,(...
# 4  InChI=1S/C19H24O3/c1-19-8-7-12-13(15(19)5-6-18...
#
#                       inchikey monisotopic_molecular_weight  \
# 0  BRMWTNUJHUMWMS-LURJTMIESA-N                169.085126611
# 1  XFNJVJPLKCPIBV-UHFFFAOYSA-N                  74.08439833
# 2  TYEYBOSBBBHJIV-UHFFFAOYSA-N                102.031694058
# 3  AFENDNXGAFYKQO-VKHMYHEASA-N                104.047344118
# 4  WHEUWNKSCXYKBU-QPWUGHHJSA-N                300.172544634
#
#   average_molecular_weight                                        description  \
# 0                 169.1811  1-Methylhistidine, also known as 1-MHis or 1MH...
# 1                  74.1249  1,3-Diaminopropane, also known as DAP or trime...
# 2                 102.0886  2-Ketobutyric acid, also known as alpha-ketobu...
# 3                  104.105  2-Hydroxybutyric acid (CAS: 600-15-7), also kn...
# 4                 300.3921  2-Methoxyestrone (or 2-ME1) belongs to the cla...
#
#                               file_name      dim
# 0    HMDB0000001_nmroned_1022_27891.txt  nmroned
# 1    HMDB0000002_nmroned_1023_27894.txt  nmroned
# 2    HMDB0000005_nmroned_1024_27899.txt  nmroned
# 3  HMDB0000008_nmroned_5245_2734397.txt  nmroned
# 4    HMDB0000010_nmroned_1026_27907.txt  nmroned

# %%
df.shape
# Out:
# (608, 15)

# %%
# Save the DataFrame to a CSV file if needed
df.to_csv('hmdb_urine/metabolites.csv', index=False)
df.drop(columns=['description']).to_csv('metabolites_no_description.csv', index=False)

# %% [markdown]
# ## Prepare the dataset for approximate lookup using the metabolyte names and synomyms

# %%
df['synonyms_cat'] = df['name'] + " " + df['synonyms'].str.join(' ')
df['synonyms_cat'] = df['synonyms_cat'].str.lower()

# %%
from rapidfuzz import process, fuzz

# Function to perform approximate lookup
def approximate_lookup(df, column, search_string, scorer1, scorer2, limit=10):
    # Extract the column values as a list
    choices = df[column].str.lower().tolist()
    names = df['name'].values
    search_string = search_string.lower()
    # Get the best matches
    matches = process.extract(search_string, choices, scorer=scorer1, score_cutoff=100, limit=None)
    #print(matches)
    if len(matches) > 0:
        result = []
        for match in matches:
            matchings_names = df.loc[match[2],['synonyms']].values[0]
            best_name = ""
            best_score = 0
            for name in [names[match[2]]] + matchings_names:
                score = scorer2(search_string, name.lower())
                if score > best_score:
                    best_score = score
                    best_name = name
            result.append([names[match[2]], best_name, match[2], best_score,])
        # Map to the main name
        matches = pd.DataFrame(result).sort_values(3, ascending=False)
        #for synomym in data['synomyns'].
        return matches.head(limit).values
    return None

# %%
df['synonyms_cat']
# Out:
# 0      1-methylhistidine [ ' ( 2 s ) - 2 - a m i n o ...
# 1      1,3-diaminopropane [ ' 1 , 3 - p r o p a n e d...
# 2      2-ketobutyric acid [ ' 2 - k e t o b u t a n o...
# 3      2-hydroxybutyric acid [ ' ( s ) - 2 - h y d r ...
# 4      2-methoxyestrone [ ' 2 - ( 8 s , 9 s , 1 3 s ,...
#                              ...
# 603    2-methylhippuric acid [ ' n - ( o - t o l u o ...
# 604    glycyl-glycine [ ' 2 - ( a m i n o a c e t a m...
# 605    3-methoxybenzenepropanoic acid [ ' 3 - m e t h...
# 606    azithromycin [ ' ( 2 r , 3 s , 4 r , 5 r , 8 r...
# 607    cytarabine [ ' 1 - b e t a - d - a r a b i n o...
# Name: synonyms_cat, Length: 608, dtype: object

# %%
matches = approximate_lookup(df, 'synonyms_cat', 'citric acid', fuzz.partial_token_ratio, fuzz.ratio, limit=3)
print(matches)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 matches = approximate_lookup(df, 'synonyms_cat', 'citric acid', fuzz.partial_token_ratio, fuzz.ratio, limit=3)
#       2 print(matches)
#
# Cell In[13], line 18, in approximate_lookup(df, column, search_string, scorer1, scorer2, limit)
#      16 best_name = ""
#      17 best_score = 0
# ---> 18 for name in [names[match[2]]] + matchings_names:
#      19     score = scorer2(search_string, name.lower())
#      20     if score > best_score:
#
# TypeError: can only concatenate list (not "str") to list

# %% [markdown]
# ## Loook for p-cresol

# %%
#matches = approximate_lookup(df, 'name', "3-hydroxybutirate")
matches = approximate_lookup(df, 'synonyms_cat', "ethylendiaminotetraacetic acid", fuzz.partial_token_ratio, fuzz.ratio, limit=3)
print(matches)
# Out:
# [['Sarcosine' 'Methylaminoacetic acid' 140 80.76923076923077]
#  ['Acetylglycine' 'Acetylaminoacetic acid' 208 76.92307692307692]
#  ['Methylimidazoleacetic acid' 'Methylimidazoleacetic acid' 528 75.0]]

# %% [markdown]
# ## Look for all metabolytes into the dataset

# %%
entries = ["2-Aminobutyric acid","2-Hydroxybutyric acid","2-Oxoglutaric acid","3-Hydroxybutyric acid","Acetic acid","Acetoacetic acid","Acetone","Alanine","Asparagine","Ca-EDTA","Choline","Citric acid","Creatine","Creatinine","D-Galactose","Dimethylsulfone","Ethanol","Formic acid","Glucose","Glutamic acid","Glutamine","Glycerol","Glycine","Histidine","Isoleucine","K-EDTA","Lactic acid","Leucine","Lysine","Methionine","N,N-Dimethylglycine","Ornithine","Phenylalanine","Proline","Pyruvic acid","Sarcosine","Succinic acid","Threonine","Trimethylamine-N-oxide","Tyrosine","Valine"]

for entry in entries:
    matches = approximate_lookup(df, 'synonyms_cat', entry, fuzz.partial_token_ratio, fuzz.ratio, limit=3)
    print(entry, matches)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 entries = ["2-Aminobutyric acid","2-Hydroxybutyric acid","2-Oxoglutaric acid","3-Hydroxybutyric acid","Acetic acid","Acetoacetic acid","Acetone","Alanine","Asparagine","Ca-EDTA","Choline","Citric acid","Creatine","Creatinine","D-Galactose","Dimethylsulfone","Ethanol","Formic acid","Glucose","Glutamic acid","Glutamine","Glycerol","Glycine","Histidine","Isoleucine","K-EDTA","Lactic acid","Leucine","Lysine","Methionine","N,N-Dimethylglycine","Ornithine","Phenylalanine","Proline","Pyruvic acid","Sarcosine","Succinic acid","Threonine","Trimethylamine-N-oxide","Tyrosine","Valine"]
#       3 for entry in entries:
# ----> 4     matches = approximate_lookup(df, 'synonyms_cat', entry, fuzz.partial_token_ratio, fuzz.ratio, limit=3)
#       5     print(entry, matches)
#
# Cell In[13], line 18, in approximate_lookup(df, column, search_string, scorer1, scorer2, limit)
#      16 best_name = ""
#      17 best_score = 0
# ---> 18 for name in [names[match[2]]] + matchings_names:
#      19     score = scorer2(search_string, name.lower())
#      20     if score > best_score:
#
# TypeError: can only concatenate list (not "str") to list

# %%
"L-Isoleucine", "L-Leucine", 'L-Valine', 'Isobutyric acid', '3-Hydroxybutyric acid', 'L-Lactic acid', 'L-Alanine', 'Acetic acid'

# %%
entries = ["Isoleucine","Leucine","Valine","Isoleucine","Valine","Isobutyrate","Ethanol","3-hydroxybutyrate","Lactate","Alanine","Acetate","3-hydroxybutyrate","Pyruvate","3-hydroxybutyrate","Succinate","Citrate","Citrate","Creatine","beta-Glucose","Ethanol","Alanine","Lactate","alpha-Glucose","Tyrosine","1-methylhistidine","Tyrosine","1-methylhistidine","Formate"]
for entry in entries:
    matches = approximate_lookup(df, 'synonyms_cat', entry, fuzz.partial_token_ratio, fuzz.ratio, limit=3)
    print(entry, matches)
# Out:
# Isoleucine [['L-Isoleucine' 'ISOLEUCINE' 88 100.0]
#  ['L-Alloisoleucine' 'Isoleucine' 211 100.0]
#  ['3-Methyl-2-oxovaleric acid' '2-Oxoisoleucine' 199 80.0]]
# Leucine [['L-Leucine' 'LEUCINE' 253 100.0]
#  ['L-Isoleucine' 'ISOLEUCINE' 88 82.35294117647058]
#  ['L-Alloisoleucine' 'Isoleucine' 211 82.35294117647058]]
# Valine [['L-Valine' 'VALINE' 336 100.0]
#  ['alpha-Ketoisovaleric acid' 'Ketovaline' 9 75.0]
#  ['L-Leucine' 'LEUCINE' 253 61.53846153846154]]
# Isoleucine [['L-Isoleucine' 'ISOLEUCINE' 88 100.0]
#  ['L-Alloisoleucine' 'Isoleucine' 211 100.0]
#  ['3-Methyl-2-oxovaleric acid' '2-Oxoisoleucine' 199 80.0]]
# Valine [['L-Valine' 'VALINE' 336 100.0]
#  ['alpha-Ketoisovaleric acid' 'Ketovaline' 9 75.0]
#  ['L-Leucine' 'LEUCINE' 253 61.53846153846154]]
# Isobutyrate [['Isobutyric acid' 'Isobutyrate' 453 100.0]
#  ['alpha-Hydroxyisobutyric acid' 'Hydroxyisobutyrate' 275
#   75.86206896551724]
#  ['2-Aminoisobutyric acid' 'a-Aminoisobutyrate' 470 75.86206896551724]]
# Ethanol [['Ethanol' 'Ethanol' 50 100.0]
#  ['Methanol' 'Methanol' 454 93.33333333333333]
#  ['L-Glutamic acid' 'Aethanolamin' 71 73.6842105263158]]
# 3-hydroxybutyrate [['3-Hydroxybutyric acid' '3-D-Hydroxybutyrate' 5 94.44444444444444]
#  ['(S)-3-Hydroxybutyric acid' 'L-3-Hydroxybutyrate' 185 94.44444444444444]
#  ['L-Threonine' '2-Amino-3-hydroxybutyrate' 85 80.95238095238095]]
# Lactate [['L-Lactic acid' 'Lactate' 96 100.0]
#  ['Indoleacetic acid' 'Lactate' 102 100.0]
#  ['D-Lactic acid' 'LACTate' 391 100.0]]
# Alanine [['L-Alanine' 'ALANINE' 81 100.0]
#  ['D-Alanine' 'Alanine' 390 100.0]
#  ['Anserine' 'Balanine' 100 93.33333333333333]]
# Acetate [['Acetic acid' 'Acetate' 20 100.0]
#  ['Acetylglycine' 'Acetate' 208 100.0]
#  ['Acetoacetic acid' 'Diacetate' 30 87.5]]
# 3-hydroxybutyrate [['3-Hydroxybutyric acid' '3-D-Hydroxybutyrate' 5 94.44444444444444]
#  ['(S)-3-Hydroxybutyric acid' 'L-3-Hydroxybutyrate' 185 94.44444444444444]
#  ['L-Threonine' '2-Amino-3-hydroxybutyrate' 85 80.95238095238095]]
# Pyruvate [['Pyruvic acid' 'Pyruvate' 127 100.0]
#  ['3-Mercaptopyruvic acid' 'Thiopyruvate' 396 80.0]
#  ['Phenylpyruvic acid' 'Phenylpyruvate' 105 72.72727272727273]]
# 3-hydroxybutyrate [['3-Hydroxybutyric acid' '3-D-Hydroxybutyrate' 5 94.44444444444444]
#  ['(S)-3-Hydroxybutyric acid' 'L-3-Hydroxybutyrate' 185 94.44444444444444]
#  ['L-Threonine' '2-Amino-3-hydroxybutyrate' 85 80.95238095238095]]
# Succinate [['Succinic acid' 'Succinate' 133 100.0]
#  ['Methylmalonic acid' 'Isosuccinate' 104 85.71428571428572]
#  ['Oxalacetic acid' 'Oxosuccinate' 115 85.71428571428572]]
# Citrate [['Citric acid' 'Citrate' 44 100.0]
#  ['Isocitric acid' 'Isocitrate' 99 82.35294117647058]
#  ['Choline' 'Choline citrate' 45 63.63636363636363]]
# Citrate [['Citric acid' 'Citrate' 44 100.0]
#  ['Isocitric acid' 'Isocitrate' 99 82.35294117647058]
#  ['Choline' 'Choline citrate' 45 63.63636363636363]]
# Creatine [['Creatine' 'Creatine' 31 100.0]
#  ['Creatinine' 'Creatinine' 212 88.88888888888889]
#  ['Phosphocreatine' 'Creatine-p' 416 88.88888888888889]]
# beta-Glucose [['D-Glucose' 'beta-Glucose' 56 100.0]]
# Ethanol [['Ethanol' 'Ethanol' 50 100.0]
#  ['Methanol' 'Methanol' 454 93.33333333333333]
#  ['L-Glutamic acid' 'Aethanolamin' 71 73.6842105263158]]
# Alanine [['L-Alanine' 'ALANINE' 81 100.0]
#  ['D-Alanine' 'Alanine' 390 100.0]
#  ['Anserine' 'Balanine' 100 93.33333333333333]]
# Lactate [['L-Lactic acid' 'Lactate' 96 100.0]
#  ['Indoleacetic acid' 'Lactate' 102 100.0]
#  ['D-Lactic acid' 'LACTate' 391 100.0]]
# alpha-Glucose None
# Tyrosine [['L-Tyrosine' 'TYROSINE' 79 100.0]
#  ['o-Tyrosine' 'o-Tyrosine' 594 88.88888888888889]
#  ['Thyroxine' 'Thyroxine' 130 82.35294117647058]]
# 1-methylhistidine [['1-Methylhistidine' '1-Methylhistidine' 0 100.0]]
# Tyrosine [['L-Tyrosine' 'TYROSINE' 79 100.0]
#  ['o-Tyrosine' 'o-Tyrosine' 594 88.88888888888889]
#  ['Thyroxine' 'Thyroxine' 130 82.35294117647058]]
# 1-methylhistidine [['1-Methylhistidine' '1-Methylhistidine' 0 100.0]]
# Formate [['Formic acid' 'Formate' 69 100.0]
#  ['Propionic acid' 'Ethylformate' 125 73.6842105263158]
#  ['Caproic acid' 'Pentiformate' 209 73.6842105263158]]

# %%
f = open('hmdb_urine/hmdb_nmr_peak_lists/HMDB0001370_nmroned_1690_31773.txt')# + df['file_name'].values[16], "r")
entry1 = f.read()
f.close()
print(entry1)
# Out:
# Table of Peaks
# No. 	(ppm) 	(Hz) 	Height
# 1 	3.76 	2256.7 	0.1688
# 2 	3.75 	2250.6 	0.3232
# 3 	3.74 	2244.6 	0.1723
# 4 	3.74 	2239.8 	0.1610
# 5 	3.73 	2233.0 	0.2302
# 6 	3.72 	2227.3 	0.1604
# 7 	1.94 	1162.6 	0.0405
# 8 	1.93 	1156.9 	0.0468
# 9 	1.92 	1153.6 	0.0572
# 10 	1.92 	1151.4 	0.0597
# 11 	1.92 	1147.9 	0.1220
# 12 	1.91 	1142.4 	0.1463
# 13 	1.90 	1137.2 	0.1818
# 14 	1.89 	1134.5 	0.1699
# 15 	1.88 	1128.4 	0.1682
# 16 	1.88 	1125.1 	0.0874
# 17 	1.87 	1121.8 	0.1179
# 18 	1.86 	1115.6 	0.0731
# 19 	1.85 	1108.1 	0.0442
# 20 	1.84 	1104.6 	0.0521
# 21 	1.83 	1096.9 	0.0279
# 22 	1.82 	1090.1 	0.0204
# 23 	1.48 	884.7 	0.0301
# 24 	1.46 	876.1 	0.0908
# 25 	1.45 	868.4 	0.1181
# 26 	1.43 	859.8 	0.0830
# 27 	1.42 	851.9 	0.0456
#
# Table of Multiplets
# No. 	Shift1 (ppm) 	Hs 	Type 	J (Hz) 	Atom1 	Multiplet1 	(ppm)
# 1 	1.45	2 	m 	- 	7 	M02 	1.36 .. 1.49
# 2 	1.88	4 	m 	- 	8 6 	M01 	1.79 .. 1.96
# 3 	3.74	2 	m 	- 	9 4 	M00 	3.70 .. 3.78
#
# Table of Assignments
# No. 	Atom Exp. 	Shift (ppm) 	Multiplet
# 1 	4 	3.74 	M00
# 2 	6 	1.88 	M01
# 3 	7 	1.45 	M02
# 4 	8 	1.88 	M01
# 5 	9 	3.74 	M00

# %% [markdown]
# # Guess the spectral frequency, compile the multiples, and recalculate the integrals that should match Hs, but sometimes has errors

# %%
import re
import pandas as pd
import math
import io

# Function to strip trailing commas
def strip_trailing_commas(s):
    if isinstance(s, str):
        return s.strip(',')
    return s


def parse_hmdb_data_clean(text, accession):
    """Parses HMDB NMR data and creates a data frame with peak information.

    Args:
        text: A string containing the HMDB NMR data in the specified format.

    Returns:
        A pandas DataFrame with one row per multiplet and columns for peak positions (ppm and Hz), heights, and assigned atoms.
    """
    text = text.lower()
    if( not( "peaks" in text )):
        text = "peaks" + text
        
    text = text.replace("muliplets", "multiplets")
    text = text.replace("mulitplets", "multiplets")
    text = text.replace("mnltiplets", "multiplets")
    text = text.replace("multuplets", "multiplets")
    text = text.replace("mutiplets", "multiplets")

    text = text.replace("praks", "peaks")
    text = text.replace("assignements", "assignments")
    
    text = text.replace("assignment\n", "assignments\n")

    text = text.replace("peaks", "peaks\n")
    text = text.replace("multiplets", "multiplets\n")
    text = text.replace("assignments", "assignments\n")
    text = text.replace("table", "\ntable")
    text = text.replace("atom exp.", "atom\texp.")

    #text = text.replace("\n\n\n", "\n\n")
    #text = text.replace(r"\n[\n]+", "\n\n")
    #print(text)
    try:
        # Extract tables using regular expressions
        table1 = re.search(r"peaks[\n ]+(.*?)\n([\t ]*)\n", text, re.DOTALL).group(1)
        #print(table1)
        table2 = re.search(r"multiplets[\n ]+(.*?)\n([\t ]*)\n", text, re.DOTALL).group(1)
        #print(multiplets_table)
        table3 = re.search(r"assignments[\n ]+(.*?)\n([\t ]*)\n", text, re.DOTALL)
        if table3 is not None:
           table3 = table3.group(1)
        else:
            table3 =  "no.\tatom\texp.shift(ppm)\tmultiplet\n1\t1\t1\1\ts0"
        #print(table2)
        # Guess which table is who
        assignments_table = None
        for table in [table1, table2, table3]:
            if "height" in table :
                peaks_table = table
            else:
                if "atom1" in table or "j (hz)" in table or "hs" in table:
                    multiplets_table = table
                else:
                    assignments_table = table
        if assignments_table == None:
            assignments_table = "no.\tatom\texp.shift(ppm)\tmultiplet\n1\t1\t1\1\ts0"
        
        multiplets_table = multiplets_table.replace("multiplet1 (ppm)", "multiplet1\t(ppm)")
        multiplets_table = re.sub(r"shift1[\s\t]*\(ppm\)", r"shift1(ppm)", multiplets_table)
        
        #print(assignments_table)

        #print(multiplets_table.replace(" ", ","))
        # Convert tables to pandas DataFrames
        peaks_df = pd.read_csv(io.StringIO(peaks_table.replace(" ", ",")), delim_whitespace=True)#sep="\t+", dtype=str)
        multiplets_df = pd.read_csv(io.StringIO(multiplets_table.replace(" ", ",")), delim_whitespace=True)
        assignments_df = pd.read_csv(io.StringIO(assignments_table.replace(" ", ",")), delim_whitespace=True)
        
        # Remove spaces in names
        peaks_df.columns = peaks_df.columns.str.replace(' ', '').str.replace(',', '')
        multiplets_df.columns = multiplets_df.columns.str.replace(' ', '').str.replace(',', '')
        assignments_df.columns = assignments_df.columns.str.replace(' ', '').str.replace(',', '')


        # Apply the function to each string column
        for col in peaks_df.select_dtypes(include=['object']).columns:
            peaks_df[col] = peaks_df[col].apply(strip_trailing_commas)
            
        # Apply the function to each string column
        for col in multiplets_df.select_dtypes(include=['object']).columns:
            multiplets_df[col] = multiplets_df[col].apply(strip_trailing_commas)  
        
        # Apply the function to each string column
        for col in assignments_df.select_dtypes(include=['object']).columns:
            assignments_df[col] = assignments_df[col].apply(strip_trailing_commas)  

        if "multiplet" not in assignments_df:
            assignments_df["multiplet"] = "x"

        peaks_df["(ppm)"] = pd.to_numeric(peaks_df["(ppm)"], errors='coerce')


        # Create an empty list to store the data for the new DataFrame
        data = []
    
        # Iterate over the multiplets
        for _, multiplet in multiplets_df.iterrows():
            if "m" not in multiplet["multiplet1"]:
                multiplet["(ppm)"] = multiplet["multiplet1"]
                multiplet["multiplet1"] = multiplet["atom1"]
                multiplet["atom1"] = ""
            if("atom1" not in multiplet):
                multiplet["atom1"] = ""
            if(isinstance(multiplet["atom1"], int) or isinstance(multiplet["atom1"], float)):
                multiplet["atom1"] = [multiplet["atom1"]]
            else:
                multiplet["atom1"] = multiplet["atom1"].split(",")

            #print(multiplet)
            if not ("j(hz)" in multiplet):
                multiplet["j(hz)"] = "-"
            if(isinstance(multiplet["j(hz)"], int) or isinstance(multiplet["j(hz)"], float)):
                 multiplet["j(hz)"] = [multiplet["j(hz)"]]
            else:
                multiplet["j(hz)"] = multiplet["j(hz)"].replace("-", "").split(",")
    
            ppm_range = multiplet["(ppm)"].replace(",", "").split("..")
            ppm_min = float(ppm_range[0])
            ppm_max = float(ppm_range[1])
            # Filter peaks within the multiplet range
            peaks_in_range = peaks_df[
                (peaks_df["(ppm)"] >= ppm_min) & (peaks_df["(ppm)"] <= ppm_max)
            ]
    
            # Extract peak information
            ppm_values = peaks_in_range["(ppm)"].tolist()
            heights = peaks_in_range["height"].tolist()
            if ("(hz)" in peaks_in_range):
                hz_values = peaks_in_range["(hz)"].tolist()
            else:
                hz_values = np.array(ppm_values) * 601
    
            # Find assigned atoms
            assigned_atoms = assignments_df[
                assignments_df["multiplet"] == multiplet["multiplet1"]
            ]["atom"].tolist()

            if "shift1(ppm)" not in multiplet:
                multiplet["shift1(ppm)"] = (ppm_min + ppm_max) / 2
            # Append data for the current multiplet to the list
            data.append(
                {
                    "accession": accession,
                    "multiplet": multiplet["multiplet1"],
                    "shift1(ppm)": multiplet["shift1(ppm)"],
                    "hs": multiplet["hs"],
                    "j(hz)": multiplet["j(hz)"],
                    "atom1": multiplet["atom1"],
                    "type": multiplet["type"],
                    "from": ppm_min,
                    "to": ppm_max,
                    "ppm": ppm_values,
                    "hz": hz_values,
                    "heights": heights,
                    "assigned atoms": assigned_atoms,
                }
            )
    
        # Create the final DataFrame
        return pd.DataFrame(data)
    except Exception as e:
        #print(text)
        print(e)
        return None;

# %%
assignment_entry = parse_hmdb_data_clean(
"""
Table of Peaks 
No. 	(ppm) 	(Hz) 	Height 
1 	3.76 	2256.7 	0.1688 
2 	3.75 	2250.6 	0.3232 
3 	3.74 	2244.6 	0.1723 
4 	3.74 	2239.8 	0.1610 
5 	3.73 	2233.0 	0.2302 
6 	3.72 	2227.3 	0.1604 
7 	1.94 	1162.6 	0.0405 
8 	1.93 	1156.9 	0.0468 
9 	1.92 	1153.6 	0.0572 
10 	1.92 	1151.4 	0.0597 
11 	1.92 	1147.9 	0.1220 
12 	1.91 	1142.4 	0.1463 
13 	1.90 	1137.2 	0.1818 
14 	1.89 	1134.5 	0.1699 
15 	1.88 	1128.4 	0.1682 
16 	1.88 	1125.1 	0.0874 
17 	1.87 	1121.8 	0.1179 
18 	1.86 	1115.6 	0.0731 
19 	1.85 	1108.1 	0.0442 
20 	1.84 	1104.6 	0.0521 
21 	1.83 	1096.9 	0.0279 
22 	1.82 	1090.1 	0.0204 
23 	1.48 	884.7 	0.0301 
24 	1.46 	876.1 	0.0908 
25 	1.45 	868.4 	0.1181 
26 	1.43 	859.8 	0.0830 
27 	1.42 	851.9 	0.0456 

Table of Multiplets 
No. 	Shift1 (ppm) 	Hs 	Type 	J (Hz) 	Atom1 	Multiplet1 	(ppm) 
1 	1.45 2 	m 	- 	7 	M02 	1.36 .. 1.49 
2 	1.88 4 	m 	- 	8 6 	M01 	1.79 .. 1.96 
3 	3.74 2 	m 	- 	9 4 	M00 	3.70 .. 3.78 
 
Table of Assignments
No. 	Atom Exp. 	Shift (ppm) 	Multiplet 
1 	4 	3.74 	M00 
2 	6 	1.88 	M01 
3 	7 	1.45 	M02 
4 	8 	1.88 	M01 
5 	9 	3.74 	M00 

""", "HMDB1")
assignment_entry
# Out:
#   accession multiplet shift1(ppm) hs   j(hz) atom1 type  from    to  \
# 0     HMDB1       m02      1.45,2  m     [7]    []    -  1.36  1.49
# 1     HMDB1       m01      1.88,4  m  [8, 6]    []    -  1.79  1.96
# 2     HMDB1       m00      3.74,2  m  [9, 4]    []    -  3.70  3.78
#
#                                                  ppm  \
# 0                     [1.48, 1.46, 1.45, 1.43, 1.42]
# 1  [1.94, 1.93, 1.92, 1.92, 1.92, 1.91, 1.9, 1.89...
# 2               [3.76, 3.75, 3.74, 3.74, 3.73, 3.72]
#
#                                                   hz  \
# 0                [884.7, 876.1, 868.4, 859.8, 851.9]
# 1  [1162.6, 1156.9, 1153.6, 1151.4, 1147.9, 1142....
# 2   [2256.7, 2250.6, 2244.6, 2239.8, 2233.0, 2227.3]
#
#                                              heights assigned atoms
# 0           [0.0301, 0.0908, 0.1181, 0.0830, 0.0456]             []
# 1  [0.0405, 0.0468, 0.0572, 0.0597, 0.1220, 0.146...             []
# 2   [0.1688, 0.3232, 0.1723, 0.1610, 0.2302, 0.1604]             []

# %%
assignment_entry = parse_hmdb_data_clean(entry1 + "\n\n", "HMDB1")
assignment_entry.head()
# Out:
# no.,	shift1(ppm),	hs,	type,	j,(hz),	atom1,	multiplet1,	(ppm),
# 1,	1.45	2,	m,	-,	7,	m02,	1.36,..,1.49,
# 2,	1.88	4,	m,	-,	8,6,	m01,	1.79,..,1.96,
# 3,	3.74	2,	m,	-,	9,4,	m00,	3.70,..,3.78,
#   accession multiplet  shift1(ppm) hs j(hz)   atom1 type  from    to  \
# 0     HMDB1       m02         1.45  2    []     [7]    m  1.36  1.49
# 1     HMDB1       m01         1.88  4    []  [8, 6]    m  1.79  1.96
# 2     HMDB1       m00         3.74  2    []  [9, 4]    m  3.70  3.78
#
#                                                  ppm  \
# 0                     [1.48, 1.46, 1.45, 1.43, 1.42]
# 1  [1.94, 1.93, 1.92, 1.92, 1.92, 1.91, 1.9, 1.89...
# 2               [3.76, 3.75, 3.74, 3.74, 3.73, 3.72]
#
#                                                   hz  \
# 0                [884.7, 876.1, 868.4, 859.8, 851.9]
# 1  [1162.6, 1156.9, 1153.6, 1151.4, 1147.9, 1142....
# 2   [2256.7, 2250.6, 2244.6, 2239.8, 2233.0, 2227.3]
#
#                                              heights assigned atoms
# 0           [0.0301, 0.0908, 0.1181, 0.0830, 0.0456]             []
# 1  [0.0405, 0.0468, 0.0572, 0.0597, 0.1220, 0.146...             []
# 2   [0.1688, 0.3232, 0.1723, 0.1610, 0.2302, 0.1604]             []

# %% [markdown]
# # Index the whole db

# %%
nmrdb = None
HMDB_PATH = 'hmdb_urine/hmdb_nmr_peak_lists/'
index = 0
count_errors = 0

for entry in df.iterrows():
    index += 1
    #531, 582
    if(index in [69, 301, 365, 387, 409, 412, 465, 493, 500, 501, 515, 531, 563, 580, 581]):
        continue
    f = open(HMDB_PATH + entry[1]['file_name'], "r")
    content = f.read()
    f.close()
    assignment_entry = parse_hmdb_data_clean(content + "\n\n", entry[1]['accession'])
    if assignment_entry is not None:
        if nmrdb is None:
            nmrdb = assignment_entry
        else:
            nmrdb = pd.concat([nmrdb, assignment_entry])
    else:
        count_errors += 1
        print(index)
        print(HMDB_PATH + entry[1]['file_name'])
        print(content)
        break;

nmrdb['from'] = pd.to_numeric(nmrdb['from'], errors='coerce')
nmrdb['to'] = pd.to_numeric(nmrdb['to'], errors='coerce')
nmrdb['shift1(ppm)'] = pd.to_numeric(nmrdb['shift1(ppm)'], errors='coerce')

nmrdb = nmrdb.sort_values("shift1(ppm)").reset_index(drop=True)

nmrdb.to_csv('inst/spectral1hnmr.csv', index=False)
print(count_errors, index)
nmrdb.shape
# Out:
# 0 608
# (3208, 13)

# %%
import bisect

# Range query function
def range_query_and(ranges, nmrdb):
    indexer = [(a, b) for a, b in zip(nmrdb['shift1(ppm)'].values, nmrdb.index.values)]
    result_ids = None
    for rng in ranges:
        left_index = bisect.bisect_left(indexer,  (rng[0], -1))
        right_index = bisect.bisect_right(indexer, (rng[1], float('inf')))
        res = set(nmrdb.loc[[item[1] for item in indexer[left_index:(right_index+1)]],['accession']]['accession'].values)
        if result_ids is None:
            result_ids = res
        else:
            result_ids = result_ids & res
    return list(result_ids)

def multiple_query(query, nmrdb, metabolytes):
    res = range_query_and(query, nmrdb)
    filtered_df = metabolytes.loc[metabolytes['accession'].isin(res), ]
    result = []
    for row in filtered_df.iterrows():
        signals = nmrdb[nmrdb['accession'] == row[1]["accession"]]
        matches = 0
        for query_i in query:
            from_i = query_i[0]
            to_i = query_i[1]
            mul_i = query_i[2]
            for signal in signals.iterrows():
                if signal[1]['shift1(ppm)'] >= from_i and signal[1]['shift1(ppm)'] <= to_i and signal[1]['type'] == mul_i:
                    matches += 1
                    break
        result.append((row[1]["accession"], row[1]["name"], len(query) / signals.shape[0] + matches /  len(query)))
                    
    result = pd.DataFrame(result, columns=["accession", "name", "similarity"])
    result = result.sort_values("similarity", ascending=False)
    return result

# %%
import pandas as pd

nmrdb = pd.read_csv("inst/spectral1hnmr.csv")
df = pd.read_csv("inst/metabolites.csv")

# %%
res = df[df['name'].isin(["L-Isoleucine", "L-Leucine", 'L-Valine', 'Isobutyric acid', '3-Hydroxybutyric acid', 'L-Lactic acid', 'L-Alanine', 'Acetic acid'])]
res = res['accession']
res
# Out:
# 5      HMDB0000011
# 20     HMDB0000042
# 81     HMDB0000161
# 88     HMDB0000172
# 96     HMDB0000190
# 253    HMDB0000687
# 336    HMDB0000883
# 453    HMDB0001873
# Name: accession, dtype: object

# %%
nmrlist = nmrdb[nmrdb['accession'].isin(res.values)]
nmrlist = nmrlist[['accession', 'ppm', 'heights', 'hs']]

nmrlist
# Out:
#         accession                                                ppm  \
# 131   HMDB0000172                              [0.913, 0.926, 0.938]
# 148   HMDB0000687                               [0.936, 0.948, 0.96]
# 163   HMDB0000883                                     [0.969, 0.983]
# 176   HMDB0000172                                     [0.991, 1.003]
# 190   HMDB0000883                                     [1.022, 1.036]
# 265   HMDB0000011                                     [1.199, 1.209]
# 272   HMDB0001873                                        [1.2, 1.21]
# 285   HMDB0000172  [1.21, 1.223, 1.235, 1.238, 1.245, 1.25, 1.257...
# 344   HMDB0000190                                      [1.31, 1.324]
# 412   HMDB0000172  [1.423, 1.432, 1.436, 1.444, 1.448, 1.457, 1.4...
# 422   HMDB0000161                                     [1.459, 1.474]
# 572   HMDB0000687  [1.631, 1.644, 1.651, 1.668, 1.676, 1.687, 1.6...
# 698   HMDB0000042                                             [1.91]
# 734   HMDB0000172  [1.936, 1.943, 1.947, 1.955, 1.959, 1.963, 1.9...
# 953   HMDB0000883  [2.229, 2.238, 2.243, 2.252, 2.257, 2.266, 2.2...
# 988   HMDB0000011                       [2.297, 2.308, 2.321, 2.332]
# 1058  HMDB0000011                        [2.396, 2.408, 2.42, 2.432]
# 1145  HMDB0001873         [2.55, 2.57, 2.58, 2.59, 2.61, 2.62, 2.64]
# 1647  HMDB0000883                                     [3.597, 3.605]
# 1700  HMDB0000172                                     [3.657, 3.664]
# 1759  HMDB0000687   [3.701, 3.712, 3.717, 3.722, 3.73, 3.734, 3.739]
# 1822  HMDB0000161                        [3.751, 3.766, 3.78, 3.795]
# 2152  HMDB0000190                       [4.084, 4.098, 4.111, 4.125]
# 2192  HMDB0000011  [4.133, 4.143, 4.154, 4.156, 4.165, 4.166, 4.1...
#
#                                                 heights  hs
# 131                      ['1.7642', '3.9743', '2.0355']   4
# 148                      ['1.9662', '4.0000', '2.1277']  57
# 163                                       [0.9681, 1.0]   3
# 176                                ['3.8784', '4.0000']   4
# 190                                     [0.953, 0.9614]   3
# 265                                       [0.9939, 1.0]   3
# 272                                ['0.9989', '0.9629']   5
# 285   ['0.0754', '0.2227', '0.2706', '0.2757', '0.31...   1
# 344                                ['0.9981', '1.0000']   4
# 412   ['0.0865', '0.1094', '0.2685', '0.3115', '0.30...   1
# 422                                ['0.9806', '1.0000']   5
# 572   ['0.0172', '0.0619', '0.2090', '0.3539', '0.27...  30
# 698                                               [1.0]   3
# 734   ['0.0413', '0.0832', '0.1421', '0.2423', '0.24...   1
# 953   [0.0276, 0.0304, 0.0702, 0.0726, 0.0941, 0.093...   1
# 988                    [0.1669, 0.1701, 0.2688, 0.2701]   1
# 1058                   [0.2314, 0.2342, 0.1437, 0.1464]   1
# 1145  ['0.0158', '0.0333', '0.0619', '0.0753', '0.05...   1
# 1647                                   [0.3374, 0.3305]   1
# 1700                               ['1.3684', '1.3908']   1
# 1759  ['0.0305', '0.2982', '0.1697', '0.5636', '0.21...   8
# 1822           ['0.0631', '0.2025', '0.2030', '0.0649']   1
# 2152           ['0.0903', '0.2701', '0.2663', '0.0860']   2
# 2192  [0.0229, 0.1039, 0.1761, 0.1379, 0.1448, 0.172...   1

# %% [markdown]
# ## Rank matches according to multiplet similarity

# %%
query = [(2.5, 2.6, 'd'), (2.6, 2.7, 'd')]

result = multiple_query(query, nmrdb, df)
result.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 query = [(2.5, 2.6, 'd'), (2.6, 2.7, 'd')]
# ----> 3 result = multiple_query(query, nmrdb, df)
#       4 result.head()
#
# NameError: name 'multiple_query' is not defined

# %%
query = [(1.25, 1.35, 'd'), (4.05, 4.15, 'q')]

result = multiple_query(query, nmrdb, df)
result.head(6)
# Out:
#      accession             name  similarity
# 1  HMDB0000190    L-Lactic acid    2.000000
# 0  HMDB0000030           Biotin    0.700000
# 2  HMDB0000701  Hexanoylglycine    0.400000
# 4  HMDB0002802        Cortisone    0.142857
# 3  HMDB0001348   SM(d18:1/18:0)    0.133333
# 5  HMDB0014352     Azithromycin    0.062500

# %%
import pandas as pd
import re

def count_atoms(formula):
    """
    Counts the number of atoms of each element in a chemical formula.

    Args:
        formula: A string representing the chemical formula.

    Returns:
        A dictionary where keys are element symbols and values are the number of atoms of that element.
    """
    atoms = {}
    for match in re.findall(r"([A-Z][a-z]*)(\d*)", formula):
        element = match[0]
        count = int(match[1]) if match[1] else 1
        atoms[element] = atoms.get(element, 0) + count
    return atoms

# Apply the function to the 'chemical_formula' column
atom_counts = df['chemical_formula'].apply(count_atoms)

# Expand the dictionary of atom counts into separate columns
#df = pd.concat([df, atom_counts.apply(pd.Series)], axis=1)
#print(df)
